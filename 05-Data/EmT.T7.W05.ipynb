# %%
! pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random 

from sklearn import linear_model

# %%
ldw = pd.read_csv("london_weather.csv")
ldw.shape
# Out:
# (15341, 10)

# %%
ldw = ldw.dropna()
ldw.shape
# Out:
# (13843, 10)

# %%
sns.heatmap(ldw.corr())
# Out:
# <Axes: >
